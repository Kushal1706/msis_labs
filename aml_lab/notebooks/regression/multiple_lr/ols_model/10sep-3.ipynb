# %%
data={
    'Hours_Studied' : [2,3,6,8,10],
    'Classes_Attended': [3,4,5,6,8],
    'Final_Score': [65,70,75,85,95]
}
#use Ordinary Least Square(OLS) Model
#predict a final score for a student who studied for 7 hours
